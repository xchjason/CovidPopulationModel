# %% [markdown]
# <a href="https://colab.research.google.com/github/xchjason/CovidPopulationModel/blob/transform/Model_Notebook(Basic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bayesian COVID Population Model
# fill in yellow values in designated Google Sheet for this model -> run this notebook in order -> give authorizations for Google Drive and Google Sheet when required -> wait for results (plot generated in this notebook, actual values updated in Google Sheet

# %% [markdown]
# ## Mount Your Google Drive
# connect your Google Drive to this Google Colab notebook through your authorization.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Go to Your Model Directory
# make sure to select the folder in your Google Drive that contains all the model/data files. The user should edit the path after 'cd'. Usually, it is cd /content/drive/MyDrive/BayesianCovidPopulationModel if you put your directory directly on your Google Drive instead of inside of another directory on your Google Drive.

# %%
cd /content/drive/MyDrive/BayesianCovidPopulationModel
# Out:
# /content/drive/MyDrive/BayesianCovidPopulationModel

# %% [markdown]
# ## Import Modules
# load in the necessary model files into this Google Colab notebook

# %%
from model import CovidModel, LogPoissonProb, get_logging_callbacks, Comp, Vax
from data import read_data, create_warmup
from sheet import *
from convert import *

# %% [markdown]
# ##Run Model
# Run the model with basic projection and update the Google Sheet with results.
# NOT INCLUDING THE CUSTOMIZED RATIOS!

# %%
model = basic_project()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/1yKfBId3RnJPFW8fEbuwKIlywTwTheDuLhGyqb0DESXU/edit#gid=0
# Successfully load in the default data. Check the specfics in GoogleSheet
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
