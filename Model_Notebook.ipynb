# %% [markdown]
# #COVID Population Model
# fill in yellow values in designated Google Sheet for this model -> run this notebook in order -> give authorizations for Google Drive and Google Sheet when required -> wait for results (plot generated in this notebook, actual values updated in Google Sheet

# %% [markdown]
# ## Mount Your Google Drive
# connect your Google Drive to this Google Colab notebook through your authorization.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Go to Your Model Directory
# make sure to select the folder in your Google Drive that contains all the model/data files

# %%
cd /content/drive/MyDrive/COVID_Project/tf_model_1p5
# Out:
# /content/drive/MyDrive/COVID_Project/tf_model_1p5

# %% [markdown]
# ## Import Modules
# load in the necessary model files into this Google Colab notebook

# %%
# %load_ext autoreload
# %autoreload 2

from model import CovidModel, Compartments, LogPoissonProb, get_logging_callbacks
from data import read_data, create_warmup
from plots import make_all_plots
from sheet import *

# %% [markdown]
# ##Run Model
# after filling in the necessary input (yellow values) in a formated Google Sheet for this model, authorize this Google Colab notebook to run the model and update the Google Sheet with results.

# %%
RunModel()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/1nLvScw4k2d79L1Rc2NxHFOupuqiEurLsqwWNtaRZB50/edit#gid=0
# Epoch 1/50
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# 1/1 [==============================] - 2s 2s/step - loss: 1939.3186
# Epoch 2/50
# 1/1 [==============================] - 3s 3s/step - loss: 1932.2932
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 1924.4279
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 1915.6788
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 1905.8335
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 1894.6499
# Epoch 7/50
# 1/1 [==============================] - 1s 1s/step - loss: 1881.8938
# Epoch 8/50
# 1/1 [==============================] - 1s 1s/step - loss: 1867.2906
# Epoch 9/50
# 1/1 [==============================] - 1s 1s/step - loss: 1850.5007
# Epoch 10/50
# 1/1 [==============================] - 1s 1s/step - loss: 1831.1244
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 1808.7130
# Epoch 12/50
# 1/1 [==============================] - 1s 1s/step - loss: 1782.7664
# Epoch 13/50
# 1/1 [==============================] - 1s 1s/step - loss: 1752.7251
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 1717.9655
# Epoch 15/50
# 1/1 [==============================] - 1s 1s/step - loss: 1677.8036
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 1631.5165
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 1578.3618
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 1517.6161
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 1448.6335
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 1370.9467
# Epoch 21/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 22/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 23/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 24/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 25/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 26/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 27/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 28/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 30/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 31/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 32/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 33/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 34/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 35/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 36/50
# 1/1 [==============================] - 1s 1s/step - loss: 613.4738
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: 582.3132
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 566.3527
# Epoch 39/50
# 1/1 [==============================] - 1s 1s/step - loss: 561.1072
# Epoch 40/50
# 1/1 [==============================] - 1s 1s/step - loss: 560.8687
# Epoch 41/50
# 1/1 [==============================] - 1s 1s/step - loss: 560.6772
# Epoch 42/50
# 1/1 [==============================] - 1s 1s/step - loss: 557.1529
# Epoch 43/50
# 1/1 [==============================] - 1s 1s/step - loss: 548.5657
# Epoch 44/50
# 1/1 [==============================] - 1s 1s/step - loss: 534.5825
# Epoch 45/50
# 1/1 [==============================] - 1s 1s/step - loss: 515.9428
# Epoch 46/50
# 1/1 [==============================] - 1s 1s/step - loss: 494.1539
# Epoch 47/50
# 1/1 [==============================] - 1s 1s/step - loss: 471.1948
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 449.1873
# Epoch 49/50
# 1/1 [==============================] - 1s 1s/step - loss: 430.0032
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 414.8178
# COVID MODEL SHEET on INFLUXES is UPDATED!
