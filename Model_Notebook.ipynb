# %% [markdown]
# <a href="https://colab.research.google.com/github/xchjason/CovidPopulationModel/blob/total_count/Model_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bayesian COVID Population Model
# fill in yellow values in designated Google Sheet for this model -> run this notebook in order -> give authorizations for Google Drive and Google Sheet when required -> wait for results (plot generated in this notebook, actual values updated in Google Sheet

# %% [markdown]
# ## Mount Your Google Drive
# connect your Google Drive to this Google Colab notebook through your authorization.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Go to Your Model Directory
# make sure to select the folder in your Google Drive that contains all the model/data files. The user should edit the path after 'cd'. Usually, it is cd /content/drive/MyDrive/theNameofYourDirectory if you put your directory directly on your Google Drive instead of inside of another directory on your Google Drive.

# %%
cd /content/drive/MyDrive/BayesianCovidPopulationModel
# Out:
# /content/drive/MyDrive/BayesianCovidPopulationModel

# %% [markdown]
# ## Import Modules
# load in the necessary model files into this Google Colab notebook

# %%
from model import CovidModel, LogPoissonProb, get_logging_callbacks, Comp, Vax
from data import read_data, create_warmup
from sheet import *

# %% [markdown]
# ## Read in the Google Sheet Link
# this link will be used later

# %%
link = read_sheet_link()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/130-vXn_6q8IWQUCcizFukW8fTPwt2oOPtx4w3zMNS04/edit#gid=0

# %% [markdown]
# ## Load Default Data
# load in default data of Rt and Vaccination Rate to Google Sheet. The user can change the Rt and Vaccination Rate before running the model. If the user wants to switch back to the default values, re-run this cell.

# %%
load_default_data(link)
# Out:
# Successfully load in the default data. Check the specfics in GoogleSheet

# %% [markdown]
# ##Run Model
# after filling in the necessary input (yellow values) in a formated Google Sheet for this model, authorize this Google Colab notebook to run the model and update the Google Sheet with results.

# %%
model = train_and_project(link)
# Out:
# Approximately 2114.0166639711706 asymptomatic people, total
# Approximately 1840.2591356576108 mild people, total
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# Epoch 1/20
# G count: -2063.8623046875
# G in: -58.839012145996094
# I count: -778.6535034179688
# D in: -2.590986490249634
# 1/1 [==============================] - 187s 187s/step - loss: 42321.7188
# Epoch 2/20
# G count: -1066.672607421875
# G in: -119.72351837158203
# I count: -28.616596221923828
# D in: -2.6318862438201904
# 1/1 [==============================] - 187s 187s/step - loss: 38181.2539
# Epoch 3/20
# G count: -553.0087280273438
# G in: -120.27545928955078
# I count: -71.93653106689453
# D in: -3.0993568897247314
# 1/1 [==============================] - 192s 192s/step - loss: 36212.9219
# Epoch 4/20
# G count: -439.6390686035156
# G in: -79.91051483154297
# I count: -68.45906829833984
# D in: -3.2823855876922607
# 1/1 [==============================] - 187s 187s/step - loss: 34811.0078
# Epoch 5/20
# G count: -312.9440002441406
# G in: -49.689517974853516
# I count: -56.81760787963867
# D in: -3.325878381729126
# 1/1 [==============================] - 183s 183s/step - loss: 33473.3086
# Epoch 6/20
# G count: -199.41690063476562
# G in: -26.856008529663086
# I count: -43.61021041870117
# D in: -3.434723377227783
# 1/1 [==============================] - 193s 193s/step - loss: 32245.6211
# Epoch 7/20
# G count: -132.5253448486328
# G in: -15.46695327758789
# I count: -33.839237213134766
# D in: -3.602186441421509
# 1/1 [==============================] - 184s 184s/step - loss: 31091.8730
# Epoch 8/20
# G count: -86.90077209472656
# G in: -9.77203369140625
# I count: -25.199007034301758
# D in: -3.868225574493408
# 1/1 [==============================] - 184s 184s/step - loss: 29972.8027
# Epoch 9/20
# G count: -57.72671890258789
# G in: -8.6032133102417
# I count: -18.350221633911133
# D in: -4.216470241546631
# 1/1 [==============================] - 191s 191s/step - loss: 28929.5195
# Epoch 10/20
# G count: -42.512760162353516
# G in: -10.453045845031738
# I count: -12.663637161254883
# D in: -4.5488996505737305
# 1/1 [==============================] - 185s 185s/step - loss: 27974.0215
# Epoch 11/20
# G count: -32.33689498901367
# G in: -14.488263130187988
# I count: -9.484808921813965
# D in: -4.901846885681152
# 1/1 [==============================] - 183s 183s/step - loss: 27019.7930
# Epoch 12/20
# G count: -26.805742263793945
# G in: -19.978900909423828
# I count: -9.870461463928223
# D in: -5.223645210266113
# 1/1 [==============================] - 185s 185s/step - loss: 26154.8008
# Epoch 13/20
# G count: -24.393033981323242
# G in: -25.96359634399414
# I count: -10.45759391784668
# D in: -5.526357173919678
# 1/1 [==============================] - 183s 183s/step - loss: 25268.4785
# Epoch 14/20
# G count: -22.597532272338867
# G in: -31.173717498779297
# I count: -10.934066772460938
# D in: -5.670915126800537
# 1/1 [==============================] - 183s 183s/step - loss: 24444.2617
# Epoch 15/20
# G count: -21.2192440032959
# G in: -36.407535552978516
# I count: -11.192154884338379
# D in: -5.808892250061035
# 1/1 [==============================] - 182s 182s/step - loss: 23648.0781
# Epoch 16/20
# G count: -20.95620346069336
# G in: -40.08018112182617
# I count: -11.449243545532227
# D in: -5.89885139465332
# 1/1 [==============================] - 184s 184s/step - loss: 22868.7773
# Epoch 17/20
# G count: -20.705955505371094
# G in: -44.50898361206055
# I count: -11.522906303405762
# D in: -6.035425662994385
# 1/1 [==============================] - 183s 183s/step - loss: 22082.8359
# Epoch 18/20
# G count: -20.166202545166016
# G in: -45.737491607666016
# I count: -11.339733123779297
# D in: -6.025196552276611
# 1/1 [==============================] - 193s 193s/step - loss: 21349.0039
# Epoch 19/20
# G count: -19.61846160888672
# G in: -46.183738708496094
# I count: -10.906105995178223
# D in: -6.045149326324463
# 1/1 [==============================] - 184s 184s/step - loss: 20656.6992
# Epoch 20/20
# G count: -19.65996551513672
# G in: -47.153812408447266
# I count: -10.248122215270996
# D in: -6.057877063751221
# 1/1 [==============================] - 184s 184s/step - loss: 19965.2500
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
