# %% [markdown]
# <a href="https://colab.research.google.com/github/xchjason/CovidPopulationModel/blob/main/Model_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #COVID Population Model
# fill in yellow values in designated Google Sheet for this model -> run this notebook in order -> give authorizations for Google Drive and Google Sheet when required -> wait for results (plot generated in this notebook, actual values updated in Google Sheet

# %% [markdown]
# ## Mount Your Google Drive
# connect your Google Drive to this Google Colab notebook through your authorization.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Go to Your Model Directory
# make sure to select the folder in your Google Drive that contains all the model/data files. The user should edit the path after 'cd'. Usually, it is cd /content/drive/MyDrive/theNameofYourDirectory if you put your directory directly on your Google Drive instead of inside of another directory on your Google Drive.

# %%
cd /content/drive/MyDrive/CovidPopulationModel
# Out:
# /content/drive/MyDrive/CovidPopulationModel

# %% [markdown]
# ## Import Modules
# load in the necessary model files into this Google Colab notebook

# %%
# %load_ext autoreload
# %autoreload 2

from model import CovidModel, Compartments, LogPoissonProb, get_logging_callbacks
from data import read_data, create_warmup
from plots import make_all_plots
from sheet import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Default Data
# load in default data of Rt and Vaccination Rate to Google Sheet. The user can change the Rt and Vaccination Rate before running the model. If the user wants to switch back to the default values, re-run this cell.

# %%
load_default_data()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/1nLvScw4k2d79L1Rc2NxHFOupuqiEurLsqwWNtaRZB50/edit#gid=0
# Successfully load in the default data. Check the specfics in GoogleSheet

# %% [markdown]
# ##Run Model
# after filling in the necessary input (yellow values) in a formated Google Sheet for this model, authorize this Google Colab notebook to run the model and update the Google Sheet with results.

# %%
run_model()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/1nLvScw4k2d79L1Rc2NxHFOupuqiEurLsqwWNtaRZB50/edit#gid=0
# Epoch 1/50
# 1/1 [==============================] - 1s 553ms/step - loss: 225.3177
# Epoch 2/50
# 1/1 [==============================] - 1s 502ms/step - loss: 222.1842
# Epoch 3/50
# 1/1 [==============================] - 1s 509ms/step - loss: 218.7078
# Epoch 4/50
# 1/1 [==============================] - 1s 519ms/step - loss: 215.5997
# Epoch 5/50
# 1/1 [==============================] - 0s 499ms/step - loss: 212.6075
# Epoch 6/50
# 1/1 [==============================] - 1s 517ms/step - loss: 209.5209
# Epoch 7/50
# 1/1 [==============================] - 1s 515ms/step - loss: 206.3837
# Epoch 8/50
# 1/1 [==============================] - 1s 580ms/step - loss: 203.2455
# Epoch 9/50
# 1/1 [==============================] - 1s 619ms/step - loss: 200.0852
# Epoch 10/50
# 1/1 [==============================] - 1s 551ms/step - loss: 196.8205
# Epoch 11/50
# 1/1 [==============================] - 1s 592ms/step - loss: 193.3828
# Epoch 12/50
# 1/1 [==============================] - 1s 555ms/step - loss: 189.7587
# Epoch 13/50
# 1/1 [==============================] - 1s 529ms/step - loss: 185.9589
# Epoch 14/50
# 1/1 [==============================] - 0s 500ms/step - loss: 181.9794
# Epoch 15/50
# 1/1 [==============================] - 1s 506ms/step - loss: 177.7826
# Epoch 16/50
# 1/1 [==============================] - 1s 507ms/step - loss: 173.3068
# Epoch 17/50
# 1/1 [==============================] - 1s 508ms/step - loss: 168.4927
# Epoch 18/50
# 1/1 [==============================] - 1s 510ms/step - loss: 163.2939
# Epoch 19/50
# 1/1 [==============================] - 1s 510ms/step - loss: 157.6657
# Epoch 20/50
# 1/1 [==============================] - 1s 511ms/step - loss: 151.5498
# Epoch 21/50
# 1/1 [==============================] - 1s 503ms/step - loss: 144.8704
# Epoch 22/50
# 1/1 [==============================] - 1s 511ms/step - loss: 137.5479
# Epoch 23/50
# 1/1 [==============================] - 1s 509ms/step - loss: 129.5229
# Epoch 24/50
# 1/1 [==============================] - 1s 509ms/step - loss: 120.7754
# Epoch 25/50
# 1/1 [==============================] - 1s 529ms/step - loss: 111.3369
# Epoch 26/50
# 1/1 [==============================] - 1s 547ms/step - loss: 101.3064
# Epoch 27/50
# 1/1 [==============================] - 1s 558ms/step - loss: 90.8827
# Epoch 28/50
# 1/1 [==============================] - 1s 570ms/step - loss: 80.4167
# Epoch 29/50
# 1/1 [==============================] - 1s 546ms/step - loss: 70.4771
# Epoch 30/50
# 1/1 [==============================] - 1s 532ms/step - loss: 61.9069
# Epoch 31/50
# 1/1 [==============================] - 1s 521ms/step - loss: 55.8197
# Epoch 32/50
# 1/1 [==============================] - 1s 512ms/step - loss: 53.3743
# Epoch 33/50
# 1/1 [==============================] - 1s 514ms/step - loss: 54.9728
# Epoch 34/50
# 1/1 [==============================] - 1s 516ms/step - loss: 58.9112
# Epoch 35/50
# 1/1 [==============================] - 1s 515ms/step - loss: 61.7431
# Epoch 36/50
# 1/1 [==============================] - 1s 506ms/step - loss: 61.3328
# Epoch 37/50
# 1/1 [==============================] - 1s 526ms/step - loss: 58.0093
# Epoch 38/50
# 1/1 [==============================] - 1s 511ms/step - loss: 53.2480
# Epoch 39/50
# 1/1 [==============================] - 1s 517ms/step - loss: 48.4889
# Epoch 40/50
# 1/1 [==============================] - 1s 527ms/step - loss: 44.6634
# Epoch 41/50
# 1/1 [==============================] - 1s 548ms/step - loss: 42.1311
# Epoch 42/50
# 1/1 [==============================] - 1s 561ms/step - loss: 40.8076
# Epoch 43/50
# 1/1 [==============================] - 1s 558ms/step - loss: 40.3539
# Epoch 44/50
# 1/1 [==============================] - 1s 566ms/step - loss: 40.3556
# Epoch 45/50
# 1/1 [==============================] - 1s 528ms/step - loss: 40.4612
# Epoch 46/50
# 1/1 [==============================] - 1s 552ms/step - loss: 40.4479
# Epoch 47/50
# 1/1 [==============================] - 1s 549ms/step - loss: 40.2151
# Epoch 48/50
# 1/1 [==============================] - 1s 710ms/step - loss: 39.7431
# Epoch 49/50
# 1/1 [==============================] - 1s 536ms/step - loss: 39.0551
# Epoch 50/50
# 1/1 [==============================] - 1s 502ms/step - loss: 38.1969
# COVID MODEL SHEET on INFLUXES is UPDATED!
