# %% [markdown]
# <a href="https://colab.research.google.com/github/xchjason/CovidPopulationModel/blob/main/Model_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #COVID Population Model
# fill in yellow values in designated Google Sheet for this model -> run this notebook in order -> give authorizations for Google Drive and Google Sheet when required -> wait for results (plot generated in this notebook, actual values updated in Google Sheet

# %% [markdown]
# ## Mount Your Google Drive
# connect your Google Drive to this Google Colab notebook through your authorization.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Go to Your Model Directory
# make sure to select the folder in your Google Drive that contains all the model/data files. The user should edit the path after 'cd'. Usually, it is cd /content/drive/MyDrive/theNameofYourDirectory if you put your directory directly on your Google Drive instead of inside of another directory on your Google Drive.

# %%
cd /content/drive/MyDrive/CovidPopulationModel
# Out:
# /content/drive/MyDrive/CovidPopulationModel

# %% [markdown]
# ## Import Modules
# load in the necessary model files into this Google Colab notebook

# %%
# %load_ext autoreload
# %autoreload 2

from model import CovidModel, Compartments, LogPoissonProb, get_logging_callbacks
from data import read_data, create_warmup
from plots import make_all_plots
from sheet import *
from project import CovidModel_Project, Compartments, LogPoissonProb, get_logging_callbacks

# %% [markdown]
# ## Read in the Google Sheet Link
# this link will be used later

# %%
link = read_sheet_link()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/1nLvScw4k2d79L1Rc2NxHFOupuqiEurLsqwWNtaRZB50/edit#gid=522053216

# %% [markdown]
# ## Load Default Data
# load in default data of Rt and Vaccination Rate to Google Sheet. The user can change the Rt and Vaccination Rate before running the model. If the user wants to switch back to the default values, re-run this cell.

# %%
load_default_data(link)
# Out:
# Successfully load in the default data. Check the specfics in GoogleSheet

# %% [markdown]
# ##Run Model
# after filling in the necessary input (yellow values) in a formated Google Sheet for this model, authorize this Google Colab notebook to run the model and update the Google Sheet with results.

# %%
model_to_be_modified = train_and_project(link)
# Out:
# Epoch 1/50
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# 1/1 [==============================] - 2s 2s/step - loss: 1934.3245
# Epoch 2/50
# 1/1 [==============================] - 1s 1s/step - loss: 1927.6003
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 1919.8186
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 1911.5089
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 1902.2798
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 1891.7339
# Epoch 7/50
# 1/1 [==============================] - 1s 1s/step - loss: 1879.6738
# Epoch 8/50
# 1/1 [==============================] - 1s 1s/step - loss: 1865.8636
# Epoch 9/50
# 1/1 [==============================] - 1s 1s/step - loss: 1849.9539
# Epoch 10/50
# 1/1 [==============================] - 1s 1s/step - loss: 1831.4849
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 1809.9661
# Epoch 12/50
# 1/1 [==============================] - 1s 1s/step - loss: 1784.8900
# Epoch 13/50
# 1/1 [==============================] - 1s 1s/step - loss: 1755.6981
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 1721.7350
# Epoch 15/50
# 1/1 [==============================] - 1s 1s/step - loss: 1682.2421
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 1636.3811
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 1583.2706
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 1522.0142
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 1451.7257
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 1371.5961
# Epoch 21/50
# 1/1 [==============================] - 2s 2s/step - loss: inf
# Epoch 22/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 23/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 24/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 25/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 26/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 27/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 28/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 30/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 31/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 32/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 33/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 34/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 35/50
# 1/1 [==============================] - 2s 2s/step - loss: inf
# Epoch 36/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 39/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 40/50
# 1/1 [==============================] - 1s 1s/step - loss: 392.7799
# Epoch 41/50
# 1/1 [==============================] - 1s 1s/step - loss: 399.5730
# Epoch 42/50
# 1/1 [==============================] - 1s 1s/step - loss: 406.1825
# Epoch 43/50
# 1/1 [==============================] - 1s 1s/step - loss: 408.9250
# Epoch 44/50
# 1/1 [==============================] - 1s 1s/step - loss: 405.9789
# Epoch 45/50
# 1/1 [==============================] - 1s 1s/step - loss: 397.0803
# Epoch 46/50
# 1/1 [==============================] - 1s 1s/step - loss: 383.1487
# Epoch 47/50
# 1/1 [==============================] - 1s 1s/step - loss: 365.9402
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 347.7145
# Epoch 49/50
# 1/1 [==============================] - 2s 2s/step - loss: 330.8692
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 317.5033

# %% [markdown]
# ## Run Trained Model with Option to Modify Learned Parameters
# user can edit the learned parameters and proceed making predictions without the need to retrain the model.
# remember to load_default_data if timeframe is changed.

# %%
modified_model = project_only(link)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
