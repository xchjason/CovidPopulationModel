# %% [markdown]
# <a href="https://colab.research.google.com/github/xchjason/CovidPopulationModel/blob/main/Model_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #COVID Population Model
# fill in yellow values in designated Google Sheet for this model -> run this notebook in order -> give authorizations for Google Drive and Google Sheet when required -> wait for results (plot generated in this notebook, actual values updated in Google Sheet

# %% [markdown]
# ## Mount Your Google Drive
# connect your Google Drive to this Google Colab notebook through your authorization.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Go to Your Model Directory
# make sure to select the folder in your Google Drive that contains all the model/data files. The user should edit the path after 'cd'. Usually, it is cd /content/drive/MyDrive/theNameofYourDirectory if you put your directory directly on your Google Drive instead of inside of another directory on your Google Drive.

# %%
cd /content/drive/MyDrive/CovidPopulationModel
# Out:
# /content/drive/MyDrive/CovidPopulationModel

# %% [markdown]
# ## Import Modules
# load in the necessary model files into this Google Colab notebook

# %%
# %load_ext autoreload
# %autoreload 2

from model import CovidModel, Compartments, LogPoissonProb, get_logging_callbacks
from data import read_data, create_warmup
from plots import make_all_plots
from sheet import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ##Run Model
# after filling in the necessary input (yellow values) in a formated Google Sheet for this model, authorize this Google Colab notebook to run the model and update the Google Sheet with results.

# %%
RunModel()
# Out:
# Enter Your Google Sheet Link: https://docs.google.com/spreadsheets/d/1nLvScw4k2d79L1Rc2NxHFOupuqiEurLsqwWNtaRZB50/edit#gid=0
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 1933.2585
# Epoch 2/50
# 1/1 [==============================] - 1s 1s/step - loss: 1926.5286
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 1918.5150
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 1909.8600
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 1900.1439
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 1888.9626
# Epoch 7/50
# 1/1 [==============================] - 1s 1s/step - loss: 1876.1642
# Epoch 8/50
# 1/1 [==============================] - 1s 1s/step - loss: 1861.5515
# Epoch 9/50
# 1/1 [==============================] - 1s 1s/step - loss: 1844.7904
# Epoch 10/50
# 1/1 [==============================] - 1s 1s/step - loss: 1825.4192
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 1802.9457
# Epoch 12/50
# 1/1 [==============================] - 1s 1s/step - loss: 1776.8722
# Epoch 13/50
# 1/1 [==============================] - 1s 1s/step - loss: 1746.6584
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 1711.6766
# Epoch 15/50
# 1/1 [==============================] - 1s 1s/step - loss: 1671.2064
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 1624.4706
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 1570.6846
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 1509.0955
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 1439.0243
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 1359.9445
# Epoch 21/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 22/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 23/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 24/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 25/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 26/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 27/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 28/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 30/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 31/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 32/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 33/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 34/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 35/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 36/50
# 1/1 [==============================] - 1s 1s/step - loss: inf
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: 536.8043
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 519.3510
# Epoch 39/50
# 1/1 [==============================] - 1s 1s/step - loss: 513.5563
# Epoch 40/50
# 1/1 [==============================] - 1s 1s/step - loss: 513.5383
# Epoch 41/50
# 1/1 [==============================] - 1s 1s/step - loss: 514.0588
# Epoch 42/50
# 1/1 [==============================] - 1s 1s/step - loss: 511.4606
# Epoch 43/50
# 1/1 [==============================] - 1s 1s/step - loss: 503.7978
# Epoch 44/50
# 1/1 [==============================] - 1s 1s/step - loss: 490.6151
# Epoch 45/50
# 1/1 [==============================] - 1s 1s/step - loss: 472.6225
# Epoch 46/50
# 1/1 [==============================] - 1s 1s/step - loss: 451.3639
# Epoch 47/50
# 1/1 [==============================] - 1s 1s/step - loss: 428.8929
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 407.4268
# Epoch 49/50
# 1/1 [==============================] - 1s 1s/step - loss: 388.9427
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 374.7350
# COVID MODEL SHEET on INFLUXES is UPDATED!
